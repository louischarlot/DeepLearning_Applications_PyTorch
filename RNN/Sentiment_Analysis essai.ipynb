# %% [markdown]
# # Sentiment Analysis of Yelp reviews: Word Embeddings and LSTM
#
# In this notebook, we implement a sentiment analysis to associate stars (from 1 to 5) to the reviews of the [YelpReviewFull dataset](https://pytorch.org/text/stable/datasets.html#yelpreviewfull).
# This dataset consists of reviews from Yelp, and is extracted from the Yelp Dataset Challenge 2015 data.
# A data point of this dataset comprises a review's text and the corresponding label (1 to 5 stars).
#
# For this, we will first use ..WORD EMBEDDINGS... TO...    [ResNet](https://arxiv.org/abs/1512.03385)
#
# Then, we will use XXX... to...    [ResNet](https://arxiv.org/abs/1512.03385)
#
# We achieve a XX% ...

# %%
# %%bash
# pip install torch==1.11.0
# pip install folium==0.2.1
# pip install torchdata
# pip install datasets
# Out:
# Requirement already satisfied: torch==1.11.0 in /Users/louis/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages (1.11.0)
# Requirement already satisfied: typing_extensions in /Users/louis/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages (from torch==1.11.0) (4.1.1)
# Requirement already satisfied: folium==0.2.1 in /Users/louis/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages (0.2.1)
# Requirement already satisfied: Jinja2 in /Users/louis/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages (from folium==0.2.1) (3.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/louis/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages (from Jinja2->folium==0.2.1) (2.0.1)
# Requirement already satisfied: torchdata in /Users/louis/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages (0.3.0)
# Requirement already satisfied: urllib3>=1.25 in /Users/louis/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages (from torchdata) (1.26.9)
# Requirement already satisfied: requests in /Users/louis/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages (from torchdata) (2.27.1)
# Requirement already satisfied: torch==1.11.0 in /Users/louis/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages (from torchdata) (1.11.0)
# Requirement already satisfied: typing_extensions in /Users/louis/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages (from torch==1.11.0->torchdata) (4.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/louis/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages (from requests->torchdata) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/louis/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages (from requests->torchdata) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/louis/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages (from requests->torchdata) (2022.5.18.1)
# Collecting datasets
#   Using cached datasets-2.2.2-py3-none-any.whl (346 kB)
# Collecting huggingface-hub<1.0.0,>=0.1.0
#   Using cached huggingface_hub-0.7.0-py3-none-any.whl (86 kB)
# Collecting pyarrow>=6.0.0
#   Using cached pyarrow-8.0.0-cp38-cp38-macosx_10_13_x86_64.whl (22.4 MB)
# Requirement already satisfied: numpy>=1.17 in /Users/louis/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages (from datasets) (1.21.2)
# Collecting fsspec[http]>=2021.05.0
#   Using cached fsspec-2022.5.0-py3-none-any.whl (140 kB)
# Collecting aiohttp
#   Using cached aiohttp-3.8.1-cp38-cp38-macosx_10_9_x86_64.whl (574 kB)
# Collecting dill<0.3.5
#   Using cached dill-0.3.4-py2.py3-none-any.whl (86 kB)
# Requirement already satisfied: pandas in /Users/louis/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages (from datasets) (1.3.3)
# Requirement already satisfied: tqdm>=4.62.1 in /Users/louis/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages (from datasets) (4.64.0)
# Collecting responses<0.19
#   Using cached responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting multiprocess
#   Using cached multiprocess-0.70.13-py38-none-any.whl (131 kB)
# Requirement already satisfied: packaging in /Users/louis/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages (from datasets) (21.0)
# Collecting xxhash
#   Using cached xxhash-3.0.0-cp38-cp38-macosx_10_9_x86_64.whl (34 kB)
# Requirement already satisfied: requests>=2.19.0 in /Users/louis/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages (from datasets) (2.27.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/louis/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (4.1.1)
# Collecting filelock
#   Using cached filelock-3.7.1-py3-none-any.whl (10 kB)
# Collecting pyyaml>=5.1
#   Using cached PyYAML-6.0-cp38-cp38-macosx_10_9_x86_64.whl (192 kB)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/louis/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages (from packaging->datasets) (2.4.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/louis/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages (from requests>=2.19.0->datasets) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/louis/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages (from requests>=2.19.0->datasets) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/louis/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages (from requests>=2.19.0->datasets) (2022.5.18.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/louis/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: attrs>=17.3.0 in /Users/louis/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages (from aiohttp->datasets) (21.2.0)
# Collecting yarl<2.0,>=1.0
#   Using cached yarl-1.7.2-cp38-cp38-macosx_10_9_x86_64.whl (121 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Using cached async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting aiosignal>=1.1.2
#   Using cached aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting frozenlist>=1.1.1
#   Using cached frozenlist-1.3.0-cp38-cp38-macosx_10_9_x86_64.whl (36 kB)
# Collecting multidict<7.0,>=4.5
#   Using cached multidict-6.0.2-cp38-cp38-macosx_10_9_x86_64.whl (28 kB)
# Collecting multiprocess
#   Using cached multiprocess-0.70.12.2-py38-none-any.whl (128 kB)
# Requirement already satisfied: pytz>=2017.3 in /Users/louis/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages (from pandas->datasets) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/louis/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/louis/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, pyyaml, pyarrow, multidict, fsspec, frozenlist, filelock, dill, async-timeout, yarl, responses, multiprocess, huggingface-hub, aiosignal, aiohttp, datasets
# Successfully installed aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.2 datasets-2.2.2 dill-0.3.4 filelock-3.7.1 frozenlist-1.3.0 fsspec-2022.5.0 huggingface-hub-0.7.0 multidict-6.0.2 multiprocess-0.70.12.2 pyarrow-8.0.0 pyyaml-6.0 responses-0.18.0 xxhash-3.0.0 yarl-1.7.2

# %% [markdown]
# ## Data pre-processing: Tokenization
#
# To begin, we download the data with the [Hugging Face](https://huggingface.co/) library datasets.
#
# (The direct loading from torchtext.datsets is impossible for now, because of a bug that will be corrected in the next version of PyTorch.)

# %%
import torch
import torch.nn as nn

DEVICE = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %%
import torchtext.transforms as T
from torch.hub import load_state_dict_from_url

padding_idx = 1
bos_idx = 0
eos_idx = 2
max_seq_len = 256
xlmr_vocab_path = r"https://download.pytorch.org/models/text/xlmr.vocab.pt"
xlmr_spm_model_path = r"https://download.pytorch.org/models/text/xlmr.sentencepiece.bpe.model"

text_transform = T.Sequential(
    T.SentencePieceTokenizer(xlmr_spm_model_path),
    T.VocabTransform(load_state_dict_from_url(xlmr_vocab_path)),
    T.Truncate(max_seq_len - 2),
    T.AddToken(token=bos_idx, begin=True),
    T.AddToken(token=eos_idx, begin=False),
)

# %%
from datasets import load_dataset
train_data = load_dataset("yelp_review_full", split="train")
test_data = load_dataset("yelp_review_full", split="test")

train_iter = iter(train_data)
test_iter = iter(test_data)
# Out:
# WARNING:datasets.builder:Reusing dataset yelp_review_full (/Users/louis/.cache/huggingface/datasets/yelp_review_full/yelp_review_full/1.0.0/e8e18e19d7be9e75642fc66b198abadb116f73599ec89a69ba5dd8d1e57ba0bf)
# WARNING:datasets.builder:Reusing dataset yelp_review_full (/Users/louis/.cache/huggingface/datasets/yelp_review_full/yelp_review_full/1.0.0/e8e18e19d7be9e75642fc66b198abadb116f73599ec89a69ba5dd8d1e57ba0bf)

# %%
from torch.utils.data import DataLoader
batch_size = 16



train_datapipe = train_iter
dev_datapipe = test_iter

# Transform the raw dataset using non-batched API (i.e apply transformation line by line)
train_datapipe = train_datapipe.map(lambda x: (text_transform(x[0]), x[1]))
train_datapipe = train_datapipe.batch(batch_size)
train_datapipe = train_datapipe.rows2columnar(["token_ids", "target"])
train_dataloader = DataLoader(train_datapipe, batch_size=None)

dev_datapipe = dev_datapipe.map(lambda x: (text_transform(x[0]), x[1]))
dev_datapipe = dev_datapipe.batch(batch_size)
dev_datapipe = dev_datapipe.rows2columnar(["token_ids", "target"])
dev_dataloader = DataLoader(dev_datapipe, batch_size=None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/xf/s_dwfc8s02d1vpprn90clnym0000gn/T/ipykernel_30613/3000896537.py in <module>
#       8
#       9 # Transform the raw dataset using non-batched API (i.e apply transformation line by line)
# ---> 10 train_datapipe = train_datapipe.map(lambda x: (text_transform(x[0]), x[1]))
#      11 train_datapipe = train_datapipe.batch(batch_size)
#      12 train_datapipe = train_datapipe.rows2columnar(["token_ids", "target"])
#
# AttributeError: 'generator' object has no attribute 'map'

# %%
num_classes = 2
input_dim = 768

from torchtext.models import RobertaClassificationHead, XLMR_BASE_ENCODER
classifier_head = RobertaClassificationHead(num_classes=num_classes, input_dim=input_dim)
model = XLMR_BASE_ENCODER.get_model(head=classifier_head)
model.to(DEVICE)
# Out:
# RobertaModel(
#   (encoder): RobertaEncoder(
#     (transformer): TransformerEncoder(
#       (token_embedding): Embedding(250002, 768, padding_idx=1)
#       (layers): ModuleList(
#         (0): TransformerEncoderLayer(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (attention): MultiheadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (input_projection): Linear(in_features=768, out_features=2304, bias=True)
#             (output_projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (residual_mlp): ResidualMLP(
#             (mlp): Sequential(
#               (0): Linear(in_features=768, out_features=3072, bias=True)
#               (1): GELU()
#               (2): Dropout(p=0.1, inplace=False)
#               (3): Linear(in_features=3072, out_features=768, bias=True)
#               (4): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (attention_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): TransformerEncoderLayer(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (attention): MultiheadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (input_projection): Linear(in_features=768, out_features=2304, bias=True)
#             (output_projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (residual_mlp): ResidualMLP(
#             (mlp): Sequential(
#               (0): Linear(in_features=768, out_features=3072, bias=True)
#               (1): GELU()
#               (2): Dropout(p=0.1, inplace=False)
#               (3): Linear(in_features=3072, out_features=768, bias=True)
#               (4): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (attention_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (2): TransformerEncoderLayer(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (attention): MultiheadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (input_projection): Linear(in_features=768, out_features=2304, bias=True)
#             (output_projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (residual_mlp): ResidualMLP(
#             (mlp): Sequential(
#               (0): Linear(in_features=768, out_features=3072, bias=True)
#               (1): GELU()
#               (2): Dropout(p=0.1, inplace=False)
#               (3): Linear(in_features=3072, out_features=768, bias=True)
#               (4): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (attention_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (3): TransformerEncoderLayer(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (attention): MultiheadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (input_projection): Linear(in_features=768, out_features=2304, bias=True)
#             (output_projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (residual_mlp): ResidualMLP(
#             (mlp): Sequential(
#               (0): Linear(in_features=768, out_features=3072, bias=True)
#               (1): GELU()
#               (2): Dropout(p=0.1, inplace=False)
#               (3): Linear(in_features=3072, out_features=768, bias=True)
#               (4): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (attention_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (4): TransformerEncoderLayer(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (attention): MultiheadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (input_projection): Linear(in_features=768, out_features=2304, bias=True)
#             (output_projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (residual_mlp): ResidualMLP(
#             (mlp): Sequential(
#               (0): Linear(in_features=768, out_features=3072, bias=True)
#               (1): GELU()
#               (2): Dropout(p=0.1, inplace=False)
#               (3): Linear(in_features=3072, out_features=768, bias=True)
#               (4): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (attention_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (5): TransformerEncoderLayer(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (attention): MultiheadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (input_projection): Linear(in_features=768, out_features=2304, bias=True)
#             (output_projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (residual_mlp): ResidualMLP(
#             (mlp): Sequential(
#               (0): Linear(in_features=768, out_features=3072, bias=True)
#               (1): GELU()
#               (2): Dropout(p=0.1, inplace=False)
#               (3): Linear(in_features=3072, out_features=768, bias=True)
#               (4): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (attention_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (6): TransformerEncoderLayer(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (attention): MultiheadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (input_projection): Linear(in_features=768, out_features=2304, bias=True)
#             (output_projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (residual_mlp): ResidualMLP(
#             (mlp): Sequential(
#               (0): Linear(in_features=768, out_features=3072, bias=True)
#               (1): GELU()
#               (2): Dropout(p=0.1, inplace=False)
#               (3): Linear(in_features=3072, out_features=768, bias=True)
#               (4): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (attention_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (7): TransformerEncoderLayer(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (attention): MultiheadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (input_projection): Linear(in_features=768, out_features=2304, bias=True)
#             (output_projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (residual_mlp): ResidualMLP(
#             (mlp): Sequential(
#               (0): Linear(in_features=768, out_features=3072, bias=True)
#               (1): GELU()
#               (2): Dropout(p=0.1, inplace=False)
#               (3): Linear(in_features=3072, out_features=768, bias=True)
#               (4): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (attention_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (8): TransformerEncoderLayer(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (attention): MultiheadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (input_projection): Linear(in_features=768, out_features=2304, bias=True)
#             (output_projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (residual_mlp): ResidualMLP(
#             (mlp): Sequential(
#               (0): Linear(in_features=768, out_features=3072, bias=True)
#               (1): GELU()
#               (2): Dropout(p=0.1, inplace=False)
#               (3): Linear(in_features=3072, out_features=768, bias=True)
#               (4): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (attention_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (9): TransformerEncoderLayer(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (attention): MultiheadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (input_projection): Linear(in_features=768, out_features=2304, bias=True)
#             (output_projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (residual_mlp): ResidualMLP(
#             (mlp): Sequential(
#               (0): Linear(in_features=768, out_features=3072, bias=True)
#               (1): GELU()
#               (2): Dropout(p=0.1, inplace=False)
#               (3): Linear(in_features=3072, out_features=768, bias=True)
#               (4): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (attention_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (10): TransformerEncoderLayer(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (attention): MultiheadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (input_projection): Linear(in_features=768, out_features=2304, bias=True)
#             (output_projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (residual_mlp): ResidualMLP(
#             (mlp): Sequential(
#               (0): Linear(in_features=768, out_features=3072, bias=True)
#               (1): GELU()
#               (2): Dropout(p=0.1, inplace=False)
#               (3): Linear(in_features=3072, out_features=768, bias=True)
#               (4): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (attention_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (11): TransformerEncoderLayer(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (attention): MultiheadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (input_projection): Linear(in_features=768, out_features=2304, bias=True)
#             (output_projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (residual_mlp): ResidualMLP(
#             (mlp): Sequential(
#               (0): Linear(in_features=768, out_features=3072, bias=True)
#               (1): GELU()
#               (2): Dropout(p=0.1, inplace=False)
#               (3): Linear(in_features=3072, out_features=768, bias=True)
#               (4): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (attention_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (positional_embedding): PositionalEmbedding(
#         (embedding): Embedding(514, 768, padding_idx=1)
#       )
#       (embedding_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (head): RobertaClassificationHead(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Linear(in_features=768, out_features=2, bias=True)
#     (activation_fn): ReLU()
#   )
# )

# %%
num_classes = 2
input_dim = 768

from torchtext.models import RobertaClassificationHead, XLMR_BASE_ENCODER

classifier_head = RobertaClassificationHead(num_classes=num_classes, input_dim=input_dim)
model = XLMR_BASE_ENCODER.get_model(head=classifier_head)
model.to(DEVICE)
# Out:
# RobertaModel(
#   (encoder): RobertaEncoder(
#     (transformer): TransformerEncoder(
#       (token_embedding): Embedding(250002, 768, padding_idx=1)
#       (layers): ModuleList(
#         (0): TransformerEncoderLayer(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (attention): MultiheadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (input_projection): Linear(in_features=768, out_features=2304, bias=True)
#             (output_projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (residual_mlp): ResidualMLP(
#             (mlp): Sequential(
#               (0): Linear(in_features=768, out_features=3072, bias=True)
#               (1): GELU()
#               (2): Dropout(p=0.1, inplace=False)
#               (3): Linear(in_features=3072, out_features=768, bias=True)
#               (4): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (attention_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): TransformerEncoderLayer(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (attention): MultiheadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (input_projection): Linear(in_features=768, out_features=2304, bias=True)
#             (output_projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (residual_mlp): ResidualMLP(
#             (mlp): Sequential(
#               (0): Linear(in_features=768, out_features=3072, bias=True)
#               (1): GELU()
#               (2): Dropout(p=0.1, inplace=False)
#               (3): Linear(in_features=3072, out_features=768, bias=True)
#               (4): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (attention_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (2): TransformerEncoderLayer(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (attention): MultiheadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (input_projection): Linear(in_features=768, out_features=2304, bias=True)
#             (output_projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (residual_mlp): ResidualMLP(
#             (mlp): Sequential(
#               (0): Linear(in_features=768, out_features=3072, bias=True)
#               (1): GELU()
#               (2): Dropout(p=0.1, inplace=False)
#               (3): Linear(in_features=3072, out_features=768, bias=True)
#               (4): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (attention_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (3): TransformerEncoderLayer(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (attention): MultiheadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (input_projection): Linear(in_features=768, out_features=2304, bias=True)
#             (output_projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (residual_mlp): ResidualMLP(
#             (mlp): Sequential(
#               (0): Linear(in_features=768, out_features=3072, bias=True)
#               (1): GELU()
#               (2): Dropout(p=0.1, inplace=False)
#               (3): Linear(in_features=3072, out_features=768, bias=True)
#               (4): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (attention_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (4): TransformerEncoderLayer(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (attention): MultiheadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (input_projection): Linear(in_features=768, out_features=2304, bias=True)
#             (output_projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (residual_mlp): ResidualMLP(
#             (mlp): Sequential(
#               (0): Linear(in_features=768, out_features=3072, bias=True)
#               (1): GELU()
#               (2): Dropout(p=0.1, inplace=False)
#               (3): Linear(in_features=3072, out_features=768, bias=True)
#               (4): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (attention_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (5): TransformerEncoderLayer(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (attention): MultiheadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (input_projection): Linear(in_features=768, out_features=2304, bias=True)
#             (output_projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (residual_mlp): ResidualMLP(
#             (mlp): Sequential(
#               (0): Linear(in_features=768, out_features=3072, bias=True)
#               (1): GELU()
#               (2): Dropout(p=0.1, inplace=False)
#               (3): Linear(in_features=3072, out_features=768, bias=True)
#               (4): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (attention_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (6): TransformerEncoderLayer(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (attention): MultiheadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (input_projection): Linear(in_features=768, out_features=2304, bias=True)
#             (output_projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (residual_mlp): ResidualMLP(
#             (mlp): Sequential(
#               (0): Linear(in_features=768, out_features=3072, bias=True)
#               (1): GELU()
#               (2): Dropout(p=0.1, inplace=False)
#               (3): Linear(in_features=3072, out_features=768, bias=True)
#               (4): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (attention_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (7): TransformerEncoderLayer(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (attention): MultiheadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (input_projection): Linear(in_features=768, out_features=2304, bias=True)
#             (output_projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (residual_mlp): ResidualMLP(
#             (mlp): Sequential(
#               (0): Linear(in_features=768, out_features=3072, bias=True)
#               (1): GELU()
#               (2): Dropout(p=0.1, inplace=False)
#               (3): Linear(in_features=3072, out_features=768, bias=True)
#               (4): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (attention_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (8): TransformerEncoderLayer(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (attention): MultiheadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (input_projection): Linear(in_features=768, out_features=2304, bias=True)
#             (output_projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (residual_mlp): ResidualMLP(
#             (mlp): Sequential(
#               (0): Linear(in_features=768, out_features=3072, bias=True)
#               (1): GELU()
#               (2): Dropout(p=0.1, inplace=False)
#               (3): Linear(in_features=3072, out_features=768, bias=True)
#               (4): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (attention_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (9): TransformerEncoderLayer(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (attention): MultiheadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (input_projection): Linear(in_features=768, out_features=2304, bias=True)
#             (output_projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (residual_mlp): ResidualMLP(
#             (mlp): Sequential(
#               (0): Linear(in_features=768, out_features=3072, bias=True)
#               (1): GELU()
#               (2): Dropout(p=0.1, inplace=False)
#               (3): Linear(in_features=3072, out_features=768, bias=True)
#               (4): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (attention_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (10): TransformerEncoderLayer(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (attention): MultiheadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (input_projection): Linear(in_features=768, out_features=2304, bias=True)
#             (output_projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (residual_mlp): ResidualMLP(
#             (mlp): Sequential(
#               (0): Linear(in_features=768, out_features=3072, bias=True)
#               (1): GELU()
#               (2): Dropout(p=0.1, inplace=False)
#               (3): Linear(in_features=3072, out_features=768, bias=True)
#               (4): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (attention_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (11): TransformerEncoderLayer(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (attention): MultiheadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (input_projection): Linear(in_features=768, out_features=2304, bias=True)
#             (output_projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (residual_mlp): ResidualMLP(
#             (mlp): Sequential(
#               (0): Linear(in_features=768, out_features=3072, bias=True)
#               (1): GELU()
#               (2): Dropout(p=0.1, inplace=False)
#               (3): Linear(in_features=3072, out_features=768, bias=True)
#               (4): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (attention_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (positional_embedding): PositionalEmbedding(
#         (embedding): Embedding(514, 768, padding_idx=1)
#       )
#       (embedding_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (head): RobertaClassificationHead(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Linear(in_features=768, out_features=2, bias=True)
#     (activation_fn): ReLU()
#   )
# )

# %%
import torchtext.functional as F
from torch.optim import AdamW

learning_rate = 1e-5
optim = AdamW(model.parameters(), lr=learning_rate)
criteria = nn.CrossEntropyLoss()


def train_step(input, target):
    output = model(input)
    loss = criteria(output, target)
    optim.zero_grad()
    loss.backward()
    optim.step()


def eval_step(input, target):
    output = model(input)
    loss = criteria(output, target).item()
    return float(loss), (output.argmax(1) == target).type(torch.float).sum().item()


def evaluate():
    model.eval()
    total_loss = 0
    correct_predictions = 0
    total_predictions = 0
    counter = 0
    with torch.no_grad():
        for batch in dev_dataloader:
            input = F.to_tensor(batch["token_ids"], padding_value=padding_idx).to(DEVICE)
            target = torch.tensor(batch["target"]).to(DEVICE)
            loss, predictions = eval_step(input, target)
            total_loss += loss
            correct_predictions += predictions
            total_predictions += len(target)
            counter += 1

    return total_loss / counter, correct_predictions / total_predictions

# %%
num_epochs = 1

for e in range(num_epochs):
    for batch in train_dataloader:
        input = F.to_tensor(batch["token_ids"], padding_value=padding_idx).to(DEVICE)
        target = torch.tensor(batch["target"]).to(DEVICE)
        train_step(input, target)

    loss, accuracy = evaluate()
    print("Epoch = [{}], loss = [{}], accuracy = [{}]".format(e, loss, accuracy))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /var/folders/xf/s_dwfc8s02d1vpprn90clnym0000gn/T/ipykernel_30613/3754204932.py in <module>
#       2
#       3 for e in range(num_epochs):
# ----> 4     for batch in train_dataloader:
#       5         input = F.to_tensor(batch["token_ids"], padding_value=padding_idx).to(DEVICE)
#       6         target = torch.tensor(batch["target"]).to(DEVICE)
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     528             if self._sampler_iter is None:
#     529                 self._reset()
# --> 530             data = self._next_data()
#     531             self._num_yielded += 1
#     532             if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     568     def _next_data(self):
#     569         index = self._next_index()  # may raise StopIteration
# --> 570         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     571         if self._pin_memory:
#     572             data = _utils.pin_memory.pin_memory(data)
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      37                 raise StopIteration
#      38         else:
# ---> 39             data = next(self.dataset_iter)
#      40         return self.collate_fn(data)
#      41
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torch/utils/data/_typing.py in wrap_generator(*args, **kwargs)
#     364             try:
#     365                 with context():
# --> 366                     response = gen.send(None)
#     367                 while True:
#     368                     request = yield response
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torchdata/datapipes/iter/util/rows2columnar.py in __iter__(self)
#      51
#      52     def __iter__(self) -> Iterator[Dict]:
# ---> 53         for batch in self.source_datapipe:
#      54             columnar = defaultdict(list)
#      55             for list_or_dict_row in batch:
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torch/utils/data/_typing.py in wrap_generator(*args, **kwargs)
#     364             try:
#     365                 with context():
# --> 366                     response = gen.send(None)
#     367                 while True:
#     368                     request = yield response
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torch/utils/data/datapipes/iter/grouping.py in __iter__(self)
#      88     def __iter__(self) -> Iterator[DataChunk]:
#      89         batch: List = []
# ---> 90         for x in self.datapipe:
#      91             batch.append(x)
#      92             if len(batch) == self.batch_size:
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torch/utils/data/_typing.py in wrap_generator(*args, **kwargs)
#     364             try:
#     365                 with context():
# --> 366                     response = gen.send(None)
#     367                 while True:
#     368                     request = yield response
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torch/utils/data/datapipes/iter/callable.py in __iter__(self)
#     110
#     111     def __iter__(self) -> Iterator[T_co]:
# --> 112         for data in self.datapipe:
#     113             yield self._apply_fn(data)
#     114
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torch/utils/data/_typing.py in wrap_generator(*args, **kwargs)
#     364             try:
#     365                 with context():
# --> 366                     response = gen.send(None)
#     367                 while True:
#     368                     request = yield response
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torch/utils/data/datapipes/iter/callable.py in __iter__(self)
#     110
#     111     def __iter__(self) -> Iterator[T_co]:
# --> 112         for data in self.datapipe:
#     113             yield self._apply_fn(data)
#     114
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torch/utils/data/_typing.py in wrap_generator(*args, **kwargs)
#     364             try:
#     365                 with context():
# --> 366                     response = gen.send(None)
#     367                 while True:
#     368                     request = yield response
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torchdata/datapipes/iter/util/plain_text_reader.py in __iter__(self)
#     146
#     147     def __iter__(self) -> Iterator[Union[D, Tuple[str, D]]]:
# --> 148         for path, file in self.source_datapipe:
#     149             stream = self._helper.skip_lines(file)
#     150             stream = self._helper.decode(stream)
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torch/utils/data/_typing.py in wrap_generator(*args, **kwargs)
#     364             try:
#     365                 with context():
# --> 366                     response = gen.send(None)
#     367                 while True:
#     368                     request = yield response
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torch/utils/data/datapipes/iter/fileopener.py in __iter__(self)
#      58     # a subtype would cause mypy error.
#      59     def __iter__(self):
# ---> 60         yield from get_file_binaries_from_pathnames(self.datapipe, self.mode, self.encoding)
#      61
#      62     def __len__(self):
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torch/utils/data/datapipes/utils/common.py in get_file_binaries_from_pathnames(pathnames, mode, encoding)
#      83         mode = 'r' + mode
#      84
# ---> 85     for pathname in pathnames:
#      86         if not isinstance(pathname, str):
#      87             raise TypeError("Expected string type for pathname, but got {}"
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torch/utils/data/_typing.py in wrap_generator(*args, **kwargs)
#     364             try:
#     365                 with context():
# --> 366                     response = gen.send(None)
#     367                 while True:
#     368                     request = yield response
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torch/utils/data/datapipes/iter/combining.py in __iter__(self)
#      44     def __iter__(self) -> Iterator:
#      45         for dp in self.datapipes:
# ---> 46             for data in dp:
#      47                 yield data
#      48
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torch/utils/data/_typing.py in wrap_generator(*args, **kwargs)
#     364             try:
#     365                 with context():
# --> 366                     response = gen.send(None)
#     367                 while True:
#     368                     request = yield response
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torch/utils/data/datapipes/iter/filelister.py in __iter__(self)
#      49
#      50     def __iter__(self) -> Iterator[str] :
# ---> 51         for path in self.datapipe:
#      52             yield from get_file_pathnames_from_root(path, self.masks, self.recursive, self.abspath, self.non_deterministic)
#      53
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torch/utils/data/_typing.py in wrap_generator(*args, **kwargs)
#     364             try:
#     365                 with context():
# --> 366                     response = gen.send(None)
#     367                 while True:
#     368                     request = yield response
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torch/utils/data/datapipes/iter/grouping.py in __iter__(self)
#     138
#     139     def __iter__(self):
# --> 140         for element in self.datapipe:
#     141             for i in self._dive(element, unbatch_level=self.unbatch_level):
#     142                 yield i
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torch/utils/data/_typing.py in wrap_generator(*args, **kwargs)
#     364             try:
#     365                 with context():
# --> 366                     response = gen.send(None)
#     367                 while True:
#     368                     request = yield response
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torch/utils/data/datapipes/iter/callable.py in __iter__(self)
#     110
#     111     def __iter__(self) -> Iterator[T_co]:
# --> 112         for data in self.datapipe:
#     113             yield self._apply_fn(data)
#     114
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torch/utils/data/_typing.py in __next__(self)
#     354         def __next__(self):
#     355             with context():
# --> 356                 return next(self.iterator)
#     357
#     358     func = namespace['__iter__']
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torch/utils/data/datapipes/iter/combining.py in get_generator_by_instance(self, instance_id)
#     188
#     189     def get_generator_by_instance(self, instance_id: int):
# --> 190         yield from self.main_datapipe.get_next_element_by_instance(self.instance_id)
#     191
#     192
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torch/utils/data/datapipes/iter/combining.py in get_next_element_by_instance(self, instance_id)
#     299             else:
#     300                 try:
# --> 301                     yield self._find_next(instance_id)
#     302                 except StopIteration:
#     303                     stop = True
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torch/utils/data/datapipes/iter/combining.py in _find_next(self, instance_id)
#     273                     "_datapipe_iterator has not been set, likely because this private method is called directly "
#     274                     "without invoking get_next_element_by_instance() first.")
# --> 275             value = next(self._datapipe_iterator)
#     276             classification = self.classifier_fn(value)
#     277             if classification is None and self.drop_none:
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torch/utils/data/_typing.py in wrap_generator(*args, **kwargs)
#     364             try:
#     365                 with context():
# --> 366                     response = gen.send(None)
#     367                 while True:
#     368                     request = yield response
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torch/utils/data/datapipes/iter/combining.py in __iter__(self)
#      44     def __iter__(self) -> Iterator:
#      45         for dp in self.datapipes:
# ---> 46             for data in dp:
#      47                 yield data
#      48
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torch/utils/data/_typing.py in wrap_generator(*args, **kwargs)
#     364             try:
#     365                 with context():
# --> 366                     response = gen.send(None)
#     367                 while True:
#     368                     request = yield response
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torchdata/datapipes/iter/util/saver.py in __iter__(self)
#      46
#      47     def __iter__(self) -> Iterator[str]:
# ---> 48         for filepath, data in self.source_datapipe:
#      49             if self.fn is not None:
#      50                 filepath = self.fn(filepath)
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torch/utils/data/_typing.py in wrap_generator(*args, **kwargs)
#     364             try:
#     365                 with context():
# --> 366                     response = gen.send(None)
#     367                 while True:
#     368                     request = yield response
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torchdata/datapipes/iter/util/hashchecker.py in __iter__(self)
#      60
#      61     def __iter__(self) -> Iterator[Tuple[str, StreamWrapper]]:
# ---> 62         for file_name, data in self.source_datapipe:
#      63             if self.hash_type == "sha256":
#      64                 hash_func = hashlib.sha256()
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torch/utils/data/_typing.py in wrap_generator(*args, **kwargs)
#     364             try:
#     365                 with context():
# --> 366                     response = gen.send(None)
#     367                 while True:
#     368                     request = yield response
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torch/utils/data/datapipes/iter/callable.py in __iter__(self)
#     110
#     111     def __iter__(self) -> Iterator[T_co]:
# --> 112         for data in self.datapipe:
#     113             yield self._apply_fn(data)
#     114
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torch/utils/data/_typing.py in wrap_generator(*args, **kwargs)
#     364             try:
#     365                 with context():
# --> 366                     response = gen.send(None)
#     367                 while True:
#     368                     request = yield response
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torch/utils/data/datapipes/iter/callable.py in __iter__(self)
#     110
#     111     def __iter__(self) -> Iterator[T_co]:
# --> 112         for data in self.datapipe:
#     113             yield self._apply_fn(data)
#     114
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torch/utils/data/_typing.py in wrap_generator(*args, **kwargs)
#     364             try:
#     365                 with context():
# --> 366                     response = gen.send(None)
#     367                 while True:
#     368                     request = yield response
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torchdata/datapipes/iter/load/online.py in __iter__(self)
#     119     def __iter__(self) -> Iterator[Tuple[str, StreamWrapper]]:
#     120         for url in self.source_datapipe:
# --> 121             yield _get_response_from_google_drive(url, timeout=self.timeout)
#     122
#     123     def __len__(self) -> int:
#
# ~/opt/anaconda3/envs/envFOAD/lib/python3.8/site-packages/torchdata/datapipes/iter/load/online.py in _get_response_from_google_drive(url, timeout)
#      83
#      84         if "content-disposition" not in response.headers:
# ---> 85             raise RuntimeError("Internal error: headers don't contain content-disposition.")
#      86
#      87         filename = re.findall('filename="(.+)"', response.headers["content-disposition"])
#
# RuntimeError: Internal error: headers don't contain content-disposition.
